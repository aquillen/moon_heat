# %%
import numpy as np
import matplotlib.pyplot as plt
import heat
# %pylab inline
# %load_ext autoreload  
# %autoreload 2
from scipy import ndimage
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pwidth = 0.15;  # how far from midplane to sum
binw= 0.05;  # binwidth
smo=2; # smoothing
xmax=1.1;  # display range
tfile = '../lib_heat_z/a1_000002_heat.txt'
ifile = '../lib_heat_z/a1_000000_heat.txt'
heat.plt3heat_init(tfile,ifile,binw,pwidth,'a1_z_3',smo,xmax)
latarrh,lonarrh,hist=heat.latlonhist(tfile,ifile,10.0)

# %%
pwidth = 0.15;  # how far from midplane to sum
binw= 0.05;  # binwidth
smo=2; # smoothing
xmax=1.1;  # display range
tfile = '../lib_heat_z/a2_000002_heat.txt'
ifile = '../lib_heat_z/a2_000000_heat.txt'
heat.plt3heat_init(tfile,ifile,binw,pwidth,'a2_z_3',smo,xmax)

# %%
pwidth = 0.15;  # how far from midplane to sum
binw= 0.05;  # binwidth
smo=2; # smoothing
xmax=1.1;  # display range
tfile = '../lib_heat_z/a3_000002_heat.txt'
ifile = '../lib_heat_z/a3_000000_heat.txt'
heat.plt3heat_init(tfile,ifile,binw,pwidth,'a3_z_3',smo,xmax)

# %%
latarrh,lonarrh,hist=heat.latlonhist(tfile,ifile,10.0)

# this is now normalized per angular area
