# %%
import numpy as np
import matplotlib.pyplot as plt
import heat
# %pylab inline
# %load_ext autoreload  
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pwidth = 0.15;  # how far from midplane to sum
binw= 0.05;  # binwidth
smo=2; # smoothing
xmax=1.1;  # display range
tfile = '../lib_heat/y1_000002_heat.txt'
ifile = '../lib_heat/y1_000000_heat.txt'
heat.plt3heat_init(tfile,ifile,binw,pwidth,'y1_3',smo,xmax)

# %%
pwidth = 0.15;   binw= 0.05;   smo=2; xmax=1.1;
tfile = '../lib_heat/y2_000003_heat.txt'
ifile = '../lib_heat/y2_000000_heat.txt'
heat.plt3heat_init(tfile,ifile,binw,pwidth,'y2_3',smo,xmax)
# this one has faster spin and semi major axis

# %%
pwidth = 0.15;   binw= 0.05;   smo=2; xmax=1.1;
tfile = '../lib_heat/outputs/y3_000003_heat.txt'
ifile = '../lib_heat/outputs/y3_000000_heat.txt'
heat.plt3heat_init(tfile,ifile,binw,pwidth,'y3_3',smo,xmax)
# like y2 but with harder core

# %%
pwidth = 0.15;   binw= 0.05;  
tfile = '../lib_heat/y4_000003_heat.txt'
ifile = '../lib_heat/y4_000000_heat.txt'
heat.plt3heat_init(tfile,ifile,binw,pwidth,'y4_3',smo,xmax)
# like y1 but with hard core

# %%
# assymetry seen in uniform bodies is seen more clearly
# in bodies with cores 
# note our core is 0.5 but that is spherical but our body is not sphereical.
# try a spherical body and see if asym persists?

# %%
pwidth = 0.15;  # how far from midplane to sum
binw= 0.05;  # binwidth
tfile = '../lib_heat/y5_000003_heat.txt'
ifile = '../lib_heat/y5_000000_heat.txt'
heat.plt3heat_init(tfile,ifile,binw,pwidth,'y5_3',smo,xmax)
# like y4 but with 0.99 axis ratios, much more round,  hard core
# lopsidedness is not strongly dependent on body axis ratio

# %%
pwidth = 0.15;   binw= 0.05;  smo=2; xmax=1.1
tfile = '../lib_heat/y6_000003_heat.txt'
ifile = '../lib_heat/y6_000000_heat.txt'
heat.plt3heat_init(tfile,ifile,binw,pwidth,'y6_3',smo,xmax)
# like y5 but with larger m1, hard core

# %%
# the answer is yes, the lopsidedness has to do with radius/semi-major
# in y6 it is 20, whereas in y5 it is 10

# %%
pwidth = 0.15;   binw= 0.05;  smo=2; xmax=1.1
tfile = '../lib_heat/outputs/yy7_000003_heat.txt'
ifile = '../lib_heat/outputs/yy7_000000_heat.txt'
heat.plt3heat_init(tfile,ifile,binw,pwidth,'y7_3',smo,xmax)
# like y6 but with lower gamma in hard core

# %%
pwidth = 0.15;   binw= 0.05;  smo=2; xmax=1.1
tfile = '../lib_heat/yy8_000003_heat.txt'
ifile = '../lib_heat/yy8_000000_heat.txt'
heat.plt3heat_init(tfile,ifile,binw,pwidth,'y8_3',smo,xmax)
# like yy7 with lower gamma in core but core is soft rather than hard
# does a hard shell give same effect of polar heating?  
#      hard but dissipating shell -> polar heating?
# Enceladus?

# %%
# mass ratio 0.0123 of moon to earth
# moon equatorial radius 1738.1 km
#a=0.3844e6 km 
print (0.3844e6/1738.0)
# current distance is 221, current heat should be nearly symmetric,
# though the moon itself is not symmetric
# Out:
# 221.17376294591483

# %%
pwidth = 0.15;   binw= 0.05;  smo=2; xmax=1.1
tfile = '../lib_heat/e1_000003_heat.txt'
ifile = '../lib_heat/e1_000000_heat.txt'
heat.plt3heat_init(tfile,ifile,binw,pwidth,'e1_3',smo,xmax)
# modelled off of enceladus with a/R = 300 or so
# and ms/me = 6e6 large mass ratio

# %%
pwidth = 0.15;   binw= 0.05;  smo=2; xmax=1.1
tfile = '../lib_heat/e2_000002_heat.txt'
ifile = '../lib_heat/e2_000000_heat.txt'
heat.plt3heat_init(tfile,ifile,binw,pwidth,'e3_3',smo,xmax)
# like e1 but soft core instead of soft shell
#  notice polar elongation here
#   if we had a soft core with low gamma we might see this better.

# %%
# hotter regions have expected higher viscosities

# %%
pwidth = 0.15;   binw= 0.05;  smo=2; xmax=1.5
tfile = '../lib_heat/h1_000003_heat.txt'
ifile = '../lib_heat/h1_000000_heat.txt'
heat.plt3heat_init(tfile,ifile,binw,pwidth,'h1_3',smo,xmax)
# a non round body just to see, started at obliquity 25

# %%
# notice obliquity tilt was present in heat_0 file
